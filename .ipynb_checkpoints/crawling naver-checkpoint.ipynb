# %%
import requests
from bs4 import BeautifulSoup

# %%
html = requests.get('https://www.naver.com/').text
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select('.PM_CL_realtimeKeyword_rolling span[class*=ah_k]')
# Out:
# []
