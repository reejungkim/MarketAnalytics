# %%
import timeit
import datetime as dt
import os
import subprocess 

import pandas as pd
import numpy as np



#visualization
import matplotlib.pyplot as plt
#import plotly.graph_objs as go
# %matplotlib inline
import seaborn as sns

#to get financial data
from pandas_datareader import data as pdr


#for webscraping 
import requests
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
import requests


#for pdf report generation
from reportlab.pdfgen import canvas
from reportlab.platypus import *
from reportlab.lib import colors
from reportlab.lib.pagesizes import letter, landscape
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
from reportlab.platypus.tableofcontents import TableOfContents
# Out:
# /Users/reejungkim/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
days_to_lookback = int (input('days to search financial data:'))
# Out:
# days to search financial data:20

# %%
date_end = dt.datetime.today()
date_start = date_end - dt.timedelta(days_to_lookback)

# %% [markdown]
# # Create timestamped folder to save reports created later

# %%
#timestamp = str(dt.datetime.now()) <- '2020-06-26 20:26:08.775766'  
timestamp =  dt.datetime.now().strftime('%Y-%m-%d %H-%M-%S')
timestamp
# Out:
# '2020-06-29 23-22-08'

# %%
path = os.getcwd() 
reportDir = os.path.join(path,timestamp)
reportDir
# Out:
# '/Users/reejungkim/Documents/Git/reporting automation/2020-06-29 23-22-08'

# %%
#create named folder
os.makedirs(reportDir, exist_ok = False)

# %%
os.chdir(reportDir)

# %% [markdown]
# # Web scraping S&P100 companies from Wikipedia table

# %%
website_url = requests.get("https://en.wikipedia.org/wiki/S%26P_100").text

soup = BeautifulSoup(website_url,'lxml')
#print(soup.prettify())

# %%
wiki_table = soup.find('table',{'class':'wikitable sortable'})

# %%
data = []
tHeader = []
SP100_tickers = pd.DataFrame()

for tr in wiki_table.find_all("tr"):
    for th in tr.find_all("th")[:1]:
        tHeader = th.get_text(strip=True)
        SP100_tickers[tHeader] = []
    for td in tr.find_all("td")[:1]:
        data.append( td.get_text(strip=True))
        
SP100_tickers[tHeader] = data

# %%
SP100_tickers
# Out:
#     Symbol
# 0     AAPL
# 1     ABBV
# 2      ABT
# 3      ACN
# 4     ADBE
# ..     ...
# 96      VZ
# 97     WBA
# 98     WFC
# 99     WMT
# 100    XOM
#
# [101 rows x 1 columns]

# %% [markdown]
# # Use DataReader to get financial data of S&P100 companies from yahoo

# %%
# %%time

df = pd.DataFrame()

for i in data:
    symbol = SP100_tickers.loc[SP100_tickers['Symbol']==i]
    try:
        symbol_data = pdr.DataReader(i, 'yahoo', date_start, date_end).reset_index()
        #display(symbol_data)  
    except ValueError: 
        print(i + " - Value Error")
        symbol_data = pdr.DataReader(i, 'yahoo', date_start, date_end).reset_index()
        #symbol_data = pd.DataFrame()
        pass
    except:
        print(i + " -Error")
        symbol_data = pd.DataFrame
    single_table = pd.concat([symbol, symbol_data], axis=0, ignore_index=True) #axis=0 <- row. add frames by row and use fill down.
    single_table['Symbol'].ffill(inplace=True)
    df = df.append(single_table)
# Out:
# BRK.B -Error
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     355                     "only Series and DataFrame objs are valid".format(typ=type(obj))
#     356                 )
# --> 357                 raise TypeError(msg)
#     358
#     359             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'type'>'; only Series and DataFrame objs are valid

# %%
df = df.loc[df['Date'].notnull()]

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# df.groupby(['Symbol']).describe().transpose()

# %%
df_Flat = df

# %% [markdown]
# # Analytics

# %% [markdown]
# ###  main data frames to be used:
# #### 1. df_Flat
# #### 2. df
# #### 3. df_Flat_pct_change

# %%
df_Flat
# Out:
#     Symbol       Date        High         Low        Open       Close  \
# 0     AAPL 2020-06-10  354.769989  346.089996  347.899994  352.839996
# 1     AAPL 2020-06-11  351.059998  335.480011  349.309998  335.899994
# 2     AAPL 2020-06-12  347.799988  334.220001  344.720001  338.799988
# 3     AAPL 2020-06-15  345.679993  332.579987  333.250000  342.989990
# 4     AAPL 2020-06-16  353.200012  344.720001  351.459991  352.079987
# ..     ...        ...         ...         ...         ...         ...
# 247    BMY 2020-06-23   59.099998   57.820000   57.939999   58.380001
# 248    BMY 2020-06-24   58.209999   57.110001   58.110001   57.759998
# 249    BMY 2020-06-25   58.470001   57.700001   58.009998   58.180000
# 250    BMY 2020-06-26   58.020000   56.669998   57.959999   57.540001
# 251    BMY 2020-06-29   58.139999   57.310001   57.990002   57.799999
#
#          Volume   Adj Close
# 0    41662900.0  352.839996
# 1    50415600.0  335.899994
# 2    50001500.0  338.799988
# 3    34702200.0  342.989990
# 4    41357200.0  352.079987
# ..          ...         ...
# 247  15557200.0   58.380001
# 248  11177200.0   57.759998
# 249  15267200.0   58.180000
# 250  26131800.0   57.540001
# 251   9570116.0   57.799999
#
# [252 rows x 8 columns]

# %%
df = df.groupby(['Symbol', 'Date']).sum()

df
# Out:
#                          High         Low        Open       Close      Volume  \
# Symbol Date
# AAPL   2020-06-10  354.769989  346.089996  347.899994  352.839996  41662900.0
#        2020-06-11  351.059998  335.480011  349.309998  335.899994  50415600.0
#        2020-06-12  347.799988  334.220001  344.720001  338.799988  50001500.0
#        2020-06-15  345.679993  332.579987  333.250000  342.989990  34702200.0
#        2020-06-16  353.200012  344.720001  351.459991  352.079987  41357200.0
# ...                       ...         ...         ...         ...         ...
# BMY    2020-06-23   59.099998   57.820000   57.939999   58.380001  15557200.0
#        2020-06-24   58.209999   57.110001   58.110001   57.759998  11177200.0
#        2020-06-25   58.470001   57.700001   58.009998   58.180000  15267200.0
#        2020-06-26   58.020000   56.669998   57.959999   57.540001  26131800.0
#        2020-06-29   58.139999   57.310001   57.990002   57.799999   9570116.0
#
#                     Adj Close
# Symbol Date
# AAPL   2020-06-10  352.839996
#        2020-06-11  335.899994
#        2020-06-12  338.799988
#        2020-06-15  342.989990
#        2020-06-16  352.079987
# ...                       ...
# BMY    2020-06-23   58.380001
#        2020-06-24   57.759998
#        2020-06-25   58.180000
#        2020-06-26   57.540001
#        2020-06-29   57.799999
#
# [252 rows x 6 columns]

# %%
df_Flat_pct_change = pd.DataFrame()

for i in df_Flat.columns.tolist():
    if i !="Symbol" and i!="Date" :
        data = df_Flat.groupby('Symbol')[i].pct_change()
        df_Flat_pct_change[i] = data

df_Flat_pct_change['Symbol'] = df_Flat['Symbol']
df_Flat_pct_change['Date'] = df_Flat['Date']

df_Flat_pct_change
cols = df_Flat.columns.tolist()
df_Flat_pct_change = df_Flat_pct_change[cols]

df_Flat_pct_change
# Out:
#     Symbol       Date      High       Low      Open     Close    Volume  \
# 0     AAPL 2020-06-10       NaN       NaN       NaN       NaN       NaN
# 1     AAPL 2020-06-11 -0.010457 -0.030657  0.004053 -0.048010  0.210084
# 2     AAPL 2020-06-12 -0.009286 -0.003756 -0.013140  0.008634 -0.008214
# 3     AAPL 2020-06-15 -0.006095 -0.004907 -0.033273  0.012367 -0.305977
# 4     AAPL 2020-06-16  0.021754  0.036503  0.054644  0.026502  0.191775
# ..     ...        ...       ...       ...       ...       ...       ...
# 247    BMY 2020-06-23  0.024441  0.033977  0.030228  0.014246 -0.168784
# 248    BMY 2020-06-24 -0.015059 -0.012279  0.002934 -0.010620 -0.281542
# 249    BMY 2020-06-25  0.004467  0.010331 -0.001721  0.007272  0.365923
# 250    BMY 2020-06-26 -0.007696 -0.017851 -0.000862 -0.011000  0.711630
# 251    BMY 2020-06-29  0.002068  0.011294  0.000518  0.004519 -0.633775
#
#      Adj Close
# 0          NaN
# 1    -0.048010
# 2     0.008634
# 3     0.012367
# 4     0.026502
# ..         ...
# 247   0.014246
# 248  -0.010620
# 249   0.007272
# 250  -0.011000
# 251   0.004519
#
# [252 rows x 8 columns]

# %%
df_temp = df.unstack(level=0).pct_change()  #df.groupby(['Symbol', 'Date']).sum().pct_change()

df_temp
# Out:
#                 High                                                    \
# Symbol          AAPL      ABBV       ABT       ACN      ADBE       AIG
# Date
# 2020-06-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-06-11 -0.010457 -0.024761 -0.002695 -0.023147 -0.014098 -0.091957
# 2020-06-12 -0.009286 -0.022190 -0.024973 -0.017092  0.018605 -0.008562
# 2020-06-15 -0.006095 -0.007494  0.001774 -0.008349 -0.013626 -0.000298
# 2020-06-16  0.021754  0.023078  0.015606  0.030587  0.021103  0.057492
# 2020-06-17  0.006229  0.009356 -0.000981 -0.002659  0.006704 -0.061127
# 2020-06-18 -0.005487 -0.006694 -0.003600 -0.015315  0.008097 -0.009901
# 2020-06-19  0.008799  0.018144  0.011605  0.025201  0.020031  0.010909
# 2020-06-22  0.008133 -0.009165 -0.018939 -0.020212  0.022550 -0.039269
# 2020-06-23  0.035943  0.018499  0.018202  0.027440  0.016403  0.021217
# 2020-06-24 -0.009641 -0.019576 -0.017010 -0.010874 -0.007800 -0.033303
# 2020-06-25 -0.010277 -0.000926 -0.010140  0.050579 -0.010572 -0.009482
# 2020-06-26  0.000877 -0.000412  0.001559 -0.004406  0.000434 -0.014678
# 2020-06-29 -0.008623  0.003092 -0.002779 -0.016319 -0.022137  0.000324
#
#                                                     ... Adj Close            \
# Symbol           ALL      AMGN       AMT      AMZN  ...       AMT      AMZN
# Date                                                ...
# 2020-06-10       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2020-06-11 -0.036250  0.001264 -0.020221 -0.018723  ... -0.052122 -0.033802
# 2020-06-12 -0.027237 -0.032335 -0.017413 -0.018679  ...  0.026122 -0.005059
# 2020-06-15  0.009333 -0.006072  0.015753 -0.014297  ...  0.017088  0.010868
# 2020-06-16  0.027131  0.035656  0.021742  0.013932  ...  0.008724  0.016555
# 2020-06-17 -0.014147 -0.000306 -0.001488  0.013359  ... -0.003059  0.009831
# 2020-06-18 -0.006322  0.011669 -0.023733  0.001748  ... -0.020048  0.004922
# 2020-06-19  0.019996  0.032789  0.014655  0.014209  ...  0.031056  0.007924
# 2020-06-22 -0.023960 -0.005940  0.003648  0.006514  ... -0.003765  0.014508
# 2020-06-23  0.007101  0.006396 -0.000075  0.025087  ... -0.000378  0.018642
# 2020-06-24 -0.034045 -0.009073 -0.013642  0.004631  ... -0.039017 -0.010856
# 2020-06-25 -0.000209 -0.006582 -0.027510 -0.014224  ...  0.000708  0.007380
# 2020-06-26 -0.001877  0.006031  0.008400  0.009557  ... -0.030980 -0.022403
# 2020-06-29  0.001881 -0.011484 -0.014084 -0.030826  ...  0.029698 -0.004638
#
#                                                                         \
# Symbol           AXP        BA       BAC      BIIB        BK      BKNG
# Date
# 2020-06-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-06-11 -0.071213 -0.164250 -0.100376 -0.040745 -0.056821 -0.083620
# 2020-06-12  0.031237  0.114765  0.035520 -0.013947  0.020170  0.022381
# 2020-06-15  0.022325  0.007546  0.014931 -0.002793 -0.000260  0.016472
# 2020-06-16  0.016065  0.035770  0.025845  0.013035  0.007546  0.013976
# 2020-06-17 -0.015717 -0.026445 -0.031008 -0.002339  0.000258 -0.021210
# 2020-06-18 -0.017314 -0.001298  0.001600 -0.075179 -0.002582 -0.006037
# 2020-06-19 -0.011942 -0.027406  0.008387  0.041106  0.015532 -0.000884
# 2020-06-22 -0.014860  0.008021 -0.024950 -0.024760 -0.017844  0.004063
# 2020-06-23 -0.000201 -0.003395  0.006905  0.014756  0.004931  0.026679
# 2020-06-24 -0.039630 -0.059559 -0.039532 -0.019203 -0.038481 -0.039813
# 2020-06-25  0.024822 -0.010244  0.038219 -0.001559  0.024711  0.003142
# 2020-06-26 -0.045273 -0.027848 -0.063511 -0.015116 -0.047969 -0.045896
# 2020-06-29  0.011775  0.143992  0.010367  0.006534  0.017346  0.033719
#
#
# Symbol           BLK       BMY
# Date
# 2020-06-10       NaN       NaN
# 2020-06-11 -0.058865 -0.057347
# 2020-06-12  0.003484 -0.009522
# 2020-06-15  0.030339 -0.019049
# 2020-06-16  0.013572  0.035572
# 2020-06-17  0.008775 -0.001928
# 2020-06-18  0.002774 -0.017208
# 2020-06-19 -0.002515  0.007861
# 2020-06-22 -0.003889  0.020386
# 2020-06-23  0.002603  0.014246
# 2020-06-24 -0.028991 -0.010620
# 2020-06-25  0.015597  0.007272
# 2020-06-26 -0.022158 -0.011000
# 2020-06-29 -0.003702  0.004519
#
# [14 rows x 108 columns]

# %% [markdown]
# ## Functions defined

# %%
def format_column_number(dataframe, listCols):
    for col in listCols:
        try:
            dataframe[col]= pd.Series([round(val, 2 ) for val in dataframe[col]], index= dataframe.index)
        except ValueError:  #skips error when the column is in format already
            dataframe[col] = dataframe[col]
            pass
    return dataframe

def format_column_percentage(dataframe, listCols):
    for col in listCols:
        try:
            dataframe[col] = pd.Series(["{0:.2f}%".format(val*100) for val in dataframe[col]], index= dataframe.index)
        except ValueError:  #skips error when the column is in format already
            dataframe[col] = dataframe[col]
        
    return dataframe

# %%
def CreatePctPlotAndSavefig(listTickers, stringTitle, stringYlabel, jpg_name):
    sns.relplot(x='Date', y='Close', kind='line', hue ='Symbol',data=df_Flat_pct_change.groupby(['Symbol', 'Date']).sum().loc[listTickers].reset_index()).fig.autofmt_xdate()
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
    plt.title(stringTitle, fontsize=16)
    plt.ylabel(stringYlabel, fontsize=14)
    plt.xlabel('Date', fontsize=14)
    #plt.tight_layout()

    jpg_name = jpg_name + '.jpg'
    plt.savefig(jpg_name, bbox_inches='tight')

def CreatePlotAndSavefig(listTickers, stringTitle, stringYlabel, jpg_name):
    sns.relplot(x='Date', y='Close', kind='line', hue ='Symbol',data=df.loc[listTickers].reset_index()).fig.autofmt_xdate()
    plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
    plt.title(stringTitle, fontsize=16)
    plt.ylabel(stringYlabel, fontsize=14)
    plt.xlabel('Date', fontsize=14)

    jpg_name = jpg_name + '.jpg'
    plt.savefig(jpg_name, bbox_inches='tight')

# %% [markdown]
# ### Best performed tickers based on percentage of of growth

# %%
tickers_bestPerformed = df_temp['Close'].describe().transpose().sort_values(by='mean', ascending=False).head(5) #df_pct_change['Close'].describe().transpose().sort_values(by='mean', ascending=False).head(5)

# %%
tickers_bestPerformed
# Out:
#         count      mean       std       min       25%       50%       75%  \
# Symbol
# ADBE     13.0  0.003517  0.025223 -0.047072 -0.012791  0.004421  0.017957
# AAPL     13.0  0.002172  0.022934 -0.048010 -0.005715  0.008634  0.021345
# ACN      13.0  0.001712  0.033439 -0.064365 -0.011062  0.001177  0.023074
# AMGN     13.0  0.001681  0.020326 -0.036192 -0.009655 -0.003967  0.011182
# AMZN     13.0  0.001067  0.015766 -0.033802 -0.005059  0.007380  0.010868
#
#              max
# Symbol
# ADBE    0.048675
# AAPL    0.026502
# ACN     0.076694
# AMGN    0.036384
# AMZN    0.018642

# %%
tickers_bestPerformed = format_column_percentage(tickers_bestPerformed, tickers_bestPerformed.columns[1:])
tickers_bestPerformed
# Out:
#         count   mean    std     min     25%     50%    75%    max
# Symbol
# ADBE     13.0  0.35%  2.52%  -4.71%  -1.28%   0.44%  1.80%  4.87%
# AAPL     13.0  0.22%  2.29%  -4.80%  -0.57%   0.86%  2.13%  2.65%
# ACN      13.0  0.17%  3.34%  -6.44%  -1.11%   0.12%  2.31%  7.67%
# AMGN     13.0  0.17%  2.03%  -3.62%  -0.97%  -0.40%  1.12%  3.64%
# AMZN     13.0  0.11%  1.58%  -3.38%  -0.51%   0.74%  1.09%  1.86%

# %%
CreatePlotAndSavefig(tickers_bestPerformed.index, 'Best performed companies based on % Changes in Close Price', 'change in closing price ($)', 'highest growth closing price')

# %%
CreatePctPlotAndSavefig(tickers_bestPerformed.index, 'Best performed companies based on % Changes in Close Price', 'change in closing price (%)', 'highest growth closing pct change')

# %% [markdown]
# ## Volatility

# %% [markdown]
# ### most volatiled companies. (based on the standard deviation of percentage change)

# %% [markdown]
# #### Top 5 companies with highest volatillity rates among S&P 100

# %%
tickers_volatile = df_temp['Close'].describe().transpose().sort_values(by='std', ascending=False).head(5)#.round(2)
tickers_volatile = format_column_percentage(tickers_volatile, tickers_volatile.columns[1:])

# %%
tickers_volatile.index
# Out:
# Index(['BA', 'BAC', 'AIG', 'BKNG', 'ACN'], dtype='object', name='Symbol')

# %%
CreatePctPlotAndSavefig(tickers_volatile.index, 'Most volatiled companies based on % Changes in Close Price', 'change in closing price (%)', '1')

# %%
CreatePlotAndSavefig(tickers_volatile.index, 'Most volatiled companies based on % Changes in Close Price', 'change in closing price ($)', '2')

# %% [markdown]
# ## Get date where highest drop and raise of closing price occured.

# %%
highest_raise = df_Flat_pct_change.groupby(['Symbol'])['Close'].transform(max) == df_Flat_pct_change['Close']
df_Flat_pct_change[highest_raise]
# Out:
#     Symbol       Date      High       Low      Open     Close    Volume  \
# 4     AAPL 2020-06-16  0.021754  0.036503  0.054644  0.026502  0.191775
# 18    ABBV 2020-06-16  0.023078  0.029742  0.039334  0.032015  0.315427
# 39     ABT 2020-06-25 -0.010140 -0.007602 -0.037405  0.026575 -0.058744
# 53     ACN 2020-06-25  0.050579  0.054863  0.036446  0.076694  0.703236
# 58    ADBE 2020-06-12  0.018605  0.020755  0.023250  0.048675  1.019837
# 72     AIG 2020-06-12 -0.008562 -0.001917  0.030769  0.045239 -0.188425
# 95     ALL 2020-06-25 -0.000209  0.003984 -0.025365  0.030984 -0.397726
# 105   AMGN 2020-06-19  0.032789  0.024947  0.028740  0.036384  1.153818
# 119    AMT 2020-06-19  0.014655 -0.000468  0.003839  0.031056  2.486910
# 135   AMZN 2020-06-23  0.025087  0.018374  0.015467  0.018642  0.318780
# 142    AXP 2020-06-12  0.004952 -0.000509  0.023198  0.031237 -0.157152
# 167     BA 2020-06-29  0.118781  0.051730  0.043709  0.143992  0.514938
# 179    BAC 2020-06-25  0.009372 -0.005490 -0.034230  0.038219 -0.137932
# 189   BIIB 2020-06-19  0.006662  0.003282  0.002566  0.041106  0.174616
# 207     BK 2020-06-25 -0.001306 -0.005914 -0.029566  0.024711 -0.028023
# 223   BKNG 2020-06-29 -0.010182  0.005533 -0.018487  0.033719 -0.424617
# 227    BLK 2020-06-15  0.019402 -0.000736 -0.037463  0.030339  0.166385
# 242    BMY 2020-06-16  0.027071  0.026447  0.005212  0.035572 -0.214846
#
#      Adj Close
# 4     0.026502
# 18    0.032015
# 39    0.026575
# 53    0.076694
# 58    0.048675
# 72    0.055928
# 95    0.030984
# 105   0.036384
# 119   0.031056
# 135   0.018642
# 142   0.031237
# 167   0.143992
# 179   0.038219
# 189   0.041106
# 207   0.024711
# 223   0.033719
# 227   0.030339
# 242   0.035572

# %%
highest_drop = df_Flat_pct_change.groupby(['Symbol'])['Close'].transform(min) == df_Flat_pct_change['Close']
drops = df_Flat_pct_change[highest_drop]

# %%
drops
# Out:
#     Symbol       Date      High       Low      Open     Close    Volume  \
# 1     AAPL 2020-06-11 -0.010457 -0.030657  0.004053 -0.048010  0.210084
# 15    ABBV 2020-06-11 -0.024761 -0.049277 -0.013403 -0.047884  0.129867
# 29     ABT 2020-06-11 -0.002695 -0.040821  0.014529 -0.047526  0.401297
# 43     ACN 2020-06-11 -0.023147 -0.048664 -0.008395 -0.064365  0.948103
# 57    ADBE 2020-06-11 -0.014098 -0.030339  0.001026 -0.047072  0.141793
# 71     AIG 2020-06-11 -0.091957 -0.109531 -0.127517 -0.100967  0.076937
# 85     ALL 2020-06-11 -0.036250 -0.067952 -0.031560 -0.070504  0.140231
# 99    AMGN 2020-06-11  0.001264 -0.030374  0.006088 -0.036192  0.368043
# 113    AMT 2020-06-11 -0.020221 -0.046195 -0.013846 -0.052122  0.589585
# 127   AMZN 2020-06-11 -0.018723 -0.034281 -0.015690 -0.033802  0.172685
# 141    AXP 2020-06-11 -0.066528 -0.073896 -0.083000 -0.071213  0.496538
# 155     BA 2020-06-11 -0.097874 -0.159017 -0.150684 -0.164250  0.141925
# 169    BAC 2020-06-11 -0.085765 -0.106752 -0.106900 -0.100376  0.657634
# 188   BIIB 2020-06-18 -0.052895 -0.074120 -0.079408 -0.075179  2.175408
# 197     BK 2020-06-11 -0.048798 -0.057272 -0.069192 -0.056821  0.251163
# 211   BKNG 2020-06-11 -0.075984 -0.082173 -0.075951 -0.083620  0.715324
# 225    BLK 2020-06-11 -0.033317 -0.062074 -0.027491 -0.058865  0.604207
# 239    BMY 2020-06-11 -0.018561 -0.058431 -0.021881 -0.057347  0.301880
#
#      Adj Close
# 1    -0.048010
# 15   -0.047884
# 29   -0.047526
# 43   -0.064365
# 57   -0.047072
# 71   -0.100967
# 85   -0.070504
# 99   -0.036192
# 113  -0.052122
# 127  -0.033802
# 141  -0.071213
# 155  -0.164250
# 169  -0.100376
# 188  -0.075179
# 197  -0.056821
# 211  -0.083620
# 225  -0.058865
# 239  -0.057347

# %%
drops['DateStr'] = drops['Date'].apply(lambda x: x.strftime('%Y/%m/%d'))
# Out:
# /Users/reejungkim/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
drops['search_key'] = drops['Symbol']  + ' ' + drops['DateStr']
# Out:
# /Users/reejungkim/opt/anaconda3/envs/myenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Search and scrap what happened to the stock on the date

# %%
search_list = drops.loc[drops['Symbol'].isin (tickers_bestPerformed.index)]['search_key'].tolist()

# %%
search_list
# Out:
# ['AAPL 2020/06/11',
#  'ACN 2020/06/11',
#  'ADBE 2020/06/11',
#  'AMGN 2020/06/11',
#  'AMZN 2020/06/11']

# %%
driver = webdriver.Chrome('/Users/reejungkim/opt/anaconda3/libexec/chromedriver')  
driver.get('https://news.google.com/topstories?hl=en-GB&tab=wn&gl=GB&ceid=GB:en')
driver.implicitly_wait(3)

# %%
xpath = '//*[@id="gb"]/div[2]/div[2]/div/form/div[1]/div/div/div/div/div[1]/input[2]'
search = driver.find_element_by_xpath(xpath)

# %%
titles = []
links = []
searched=[]

for keyword in search_list:
    driver.implicitly_wait(30)
    search.clear()
    search.send_keys(keyword)
    search.send_keys(Keys.ENTER)
    driver.implicitly_wait(30)

    url = driver.current_url
    resp = requests.get(url)
    soup = BeautifulSoup(resp.text, 'lxml')

    for link in soup.select('h3 >a')[:5]:
        href = 'https://news.google.com' + link.get('href')[1:]
        title = link.string
        searched.append(keyword)
        titles.append(title)
        links.append(href)
    
    search.clear()

# %%
search.clear()
search.send_keys('aapl')

# %%
news_data = { 'searched keyword': searched, 'title': titles, 'link': links}
news_df = pd.DataFrame(news_data, columns=['searched keyword','title', 'link'])

# %% [markdown]
# news_df['link'] = "<a href=" + "\"{" + news_df['link'] + "}" + "\"" + ">Click</a>"

# %%
news_df
# Out:
#    searched keyword                                              title  \
# 0    ACN 2020/06/11  Accenture Plc (NYSE:ACN) crossed MACD bearish ...
# 1    ACN 2020/06/11  Japan Corporate News - Bigtincan(R) Announces ...
# 2    ACN 2020/06/11  TOPIC PAGE: Coronavirus, oil price crash – imp...
# 3    ACN 2020/06/11  The first A+H+G insurance company is ready to ...
# 4    ACN 2020/06/11  CropLife Asia Commends UN Call for Action to A...
# 5   ADBE 2020/06/11       How Cloud Solutions Brought Adobe to the Top
# 6   ADBE 2020/06/11  Adobe stock rises as coronavirus work-from-hom...
# 7   ADBE 2020/06/11  Edited Transcript of ADBE earnings conference ...
# 8   ADBE 2020/06/11                7 Stocks To Watch For June 11, 2020
# 9   ADBE 2020/06/11  S&P 500 Earnings Preview - Adobe Headlines Thu...
# 10  AMGN 2020/06/11   July 31st Options Now Available For Amgen (AMGN)
# 11  AMGN 2020/06/11      Top Stock Reports for Facebook, Adobe & Amgen
# 12  AMGN 2020/06/11             Biotech ETFs: Appraising The Pipelines
# 13  AMGN 2020/06/11  The Extreme Risks of Trading Your Own Retireme...
# 14  AMGN 2020/06/11  The Zacks Analyst Blog Highlights: Tesla, PayP...
# 15  AMZN 2020/06/11                 Better Buy: Amazon.com vs. Walmart
# 16  AMZN 2020/06/11  Amazon to reportedly face antitrust charges in...
# 17  AMZN 2020/06/11  Dow rises more than 400 points, but Wall Stree...
# 18  AMZN 2020/06/11  Ex Amazon VP who called company 'chickens--t' ...
# 19  AMZN 2020/06/11  Stocks making the biggest moves in the premark...
#
#                                                  link
# 0   https://news.google.com/articles/CBMid2h0dHBzO...
# 1   https://news.google.com/articles/CBMixQFodHRwO...
# 2   https://news.google.com/articles/CBMiemh0dHBzO...
# 3   https://news.google.com/articles/CBMifmh0dHBzO...
# 4   https://news.google.com/articles/CBMiT2h0dHBzO...
# 5   https://news.google.com/articles/CBMiW2h0dHBzO...
# 6   https://news.google.com/articles/CAIiEEKuzfAQn...
# 7   https://news.google.com/articles/CBMiWGh0dHBzO...
# 8   https://news.google.com/articles/CBMiWGh0dHBzO...
# 9   https://news.google.com/articles/CBMidGh0dHBzO...
# 10  https://news.google.com/articles/CBMiWWh0dHBzO...
# 11  https://news.google.com/articles/CAIiEBJ57OvJM...
# 12  https://news.google.com/articles/CAIiEJoM21ror...
# 13  https://news.google.com/articles/CAIiEMYqLT2TD...
# 14  https://news.google.com/articles/CAIiEE9WmesT5...
# 15  https://news.google.com/articles/CBMiTmh0dHBzO...
# 16  https://news.google.com/articles/CAIiELZlMcewN...
# 17  https://news.google.com/articles/CAIiEADs7woBV...
# 18  https://news.google.com/articles/CAIiECZ6ylkhP...
# 19  https://news.google.com/articles/CAIiEHgL8BRnh...

# %%
news_df.to_csv('./news.csv')

# %% [markdown]
# #Open pdf file generated
# subprocess.run(['open', './news.csv'], check=True)

# %% [markdown]
# ## S&P 100 total

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot(x='Date', y='Close', kind='line', data=df_Flat).fig.autofmt_xdate()

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.title('S&P100 Total', fontsize=16)
plt.ylabel('Close', fontsize=14)
plt.xlabel('Date', fontsize=14)

jpg_name = 'SP100_total.jpg'
plt.savefig(jpg_name, bbox_inches='tight')

# %% [markdown]
# pd.options.display.float_format = '{:,.2%}'.format
# display(tickers_volatile), display(tickers_bestPerformed)

# %%
#pd.options.display.float_format = '{:,.2f}'.format
dataToExport = df.loc[tickers_bestPerformed.index].unstack(0).describe()
dataToExport = dataToExport.transpose().reset_index().groupby(['Symbol', 'level_0']).sum().round(2)

dataToExport.rename_axis(index={"level_0":"Type"}, inplace=True)
dataToExport
# Out:
#                   count         mean          std          min          25%  \
# Symbol Type
# AAPL   Adj Close   14.0       352.95         9.18       335.90       350.19
#        Close       14.0       352.95         9.18       335.90       350.19
#        High        14.0       357.93         7.90       345.68       353.26
#        Low         14.0       348.03         9.07       332.58       344.83
#        Open        14.0       353.32         8.62       333.25       349.82
#        Volume      14.0  42057786.57  11625559.11  24205100.00  33991125.00
# ACN    Adj Close   14.0       205.37         5.84       195.95       201.65
#        Close       14.0       205.37         5.84       195.95       201.65
#        High        14.0       208.14         5.18       200.74       204.55
#        Low         14.0       202.75         5.46       194.83       199.33
#        Open        14.0       205.76         5.21       196.49       202.14
#        Volume      14.0   2722300.14    893278.53   1594800.00   2166450.00
# ADBE   Adj Close   14.0       419.64        15.64       387.67       408.03
#        Close       14.0       419.64        15.64       387.67       408.03
#        High        14.0       424.76        14.41       404.20       412.46
#        Low         14.0       413.51        14.79       387.37       400.99
#        Open        14.0       419.21        14.94       398.80       408.20
#        Volume      14.0   3603484.14   1506689.90   2111000.00   2700275.00
# AMGN   Adj Close   14.0       229.11         6.60       217.90       226.19
#        Close       14.0       229.11         6.60       217.90       226.19
#        High        14.0       232.22         5.84       221.00       229.03
#        Low         14.0       226.18         6.71       213.86       223.10
#        Open        14.0       229.28         6.18       215.81       226.72
#        Volume      14.0   2765637.14    939822.30   1771520.00   2212875.00
# AMZN   Adj Close   14.0      2660.63        70.06      2545.02      2621.70
#        Close       14.0      2660.63        70.06      2545.02      2621.70
#        High        14.0      2697.21        66.35      2584.00      2656.16
#        Low         14.0      2629.65        74.00      2503.35      2588.57
#        Open        14.0      2668.86        71.06      2526.60      2626.25
#        Volume      14.0   4310380.79   1232936.21   2487800.00   3303000.00
#
#                           50%          75%          max
# Symbol Type
# AAPL   Adj Close       352.46       359.76       366.53
#        Close           352.46       359.76       366.53
#        High            355.98       364.29       372.38
#        Low             350.15       352.59       362.27
#        Open            352.35       359.31       365.00
#        Volume     41510050.00  50312075.00  66119000.00
# ACN    Adj Close       203.66       208.92       217.32
#        Close           203.66       208.92       217.32
#        High            207.14       210.54       217.89
#        Low             201.82       205.77       211.50
#        Open            205.51       207.47       216.78
#        Volume      2382650.00   3199725.00   4690200.00
# ADBE   Adj Close       422.33       430.76       440.55
#        Close           422.33       430.76       440.55
#        High            424.66       438.13       446.15
#        Low             414.53       426.78       436.01
#        Open            418.88       429.75       440.07
#        Volume      3470500.00   3817125.00   8329200.00
# AMGN   Adj Close       230.94       233.85       238.70
#        Close           230.94       233.85       238.70
#        High            232.81       236.97       239.17
#        Low             227.83       231.38       233.44
#        Open            230.02       234.50       236.31
#        Volume      2470800.00   2826250.00   5319500.00
# AMZN   Adj Close      2664.49      2708.58      2764.41
#        Close          2664.49      2708.58      2764.41
#        High           2697.11      2747.76      2796.00
#        Low            2633.97      2683.25      2721.00
#        Open           2662.79      2717.02      2780.00
#        Volume      4157565.50   5308700.00   6483800.00

# %%
#format_column_percentage(dataToExport, dataToExport.columns[1:])

# %% [markdown]
# dataToExport2 = df.loc[tickers_bestPerformed.index].unstack(0).describe().stack(0)
# dataToExport2

# %% [markdown]
# # Create PDF file

# %%
today = dt.datetime.today().strftime('%Y-%m-%d')
pdf_file_name = "Report "+ today +".pdf"

# %%
def PrepareTableForReportLab(dataframe):
    
    data = dataframe

    'handling grouped first index column'
    a= []
    for i in range(len(data)):
        #print(i, data.index.get_level_values(0)[i])
        if data.index.get_level_values(0)[i-1] == data.index.get_level_values(0)[i]:
            a.append(i)
    a.sort(reverse=True)

    as_list = data.index.get_level_values(0).tolist()
    for i in a:
        as_list[i] = ""

        
    'flat dataframe'
    data = data.reset_index()
    'remove duplicated values from first column which was index before resetting index'
    first_col_name = data.columns[0]
    data[first_col_name] = as_list 
    
    #data = dataframe.reset_index()
    #colwidths = 800/len(data.columns) 
    data = [data.columns.to_list()] + data.values.tolist() 

    #tbl = Table(data) # 
    tbl = Table(data) #, colwidths ) #, rowheights)
    tbl.setStyle(TableStyle([
    ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black),
    ('BOX', (0, 0), (-1, -1), 0.25, colors.black),
    ('ALIGN', (1,1), (-1,-1), 'RIGHT'),
    ('BACKGROUND', (0,0), (-1,0), colors.Color(0,0.7,0.7))
    ]))
    
    return tbl

# %% [markdown]
# def PrepareTableForReportLab_News_df(dataframe):
#
#     data = dataframe
#
#     'handling grouped first index column'
#     a= []
#     for i in range(len(data)):
#         #print(i, data.index.get_level_values(0)[i])
#         if data.index.get_level_values(0)[i-1] == data.index.get_level_values(0)[i]:
#             a.append(i)
#     a.sort(reverse=True)
#
#     as_list = data.index.get_level_values(0).tolist()
#     for i in a:
#         as_list[i] = ""
#
#
#     'flat dataframe'
#     data = data.reset_index()
#     'remove duplicated values from first column which was index before resetting index'
#     first_col_name = data.columns[0]
#     data[first_col_name] = as_list
#
#     #data = dataframe.reset_index()
#     colwidths = 800/len(data.columns)
#     rowheights = 1.5*inch
#     data = [data.columns.to_list()] + data.values.tolist()
#
#     #tbl = Table(data) #
#     tbl = Table(data , colwidths, rowheights)
#     tbl.setStyle(TableStyle([
#     ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black),
#     ('BOX', (0, 0), (-1, -1), 0.25, colors.black),
#     ('ALIGN', (1,1), (-1,-1), 'RIGHT'),
#     ('BACKGROUND', (0,0), (-1,0), colors.Color(0,0.7,0.7))
#     ]))
#
#     return tbl

# %%
story = []

# %%
story.append(Paragraph("Highest growth rates", getSampleStyleSheet()['Heading1']))
story.append(Paragraph("highest growth rates in past <i>" + str(days_to_lookback) + " days</i>.",  getSampleStyleSheet()['Normal']))
story.append(Spacer(1,20))
story.append((PrepareTableForReportLab(dataToExport)))
story.append(Spacer(1,20))
story.append(PrepareTableForReportLab(tickers_bestPerformed))
story.append(PageBreak())

story.append(Paragraph("Volatility", getSampleStyleSheet()['Heading1']))
story.append(Paragraph("highest volatility rates in past <i>" + str(days_to_lookback)  + " days</i>.",  getSampleStyleSheet()['Normal']))
story.append(Spacer(1,20))
story.append(PrepareTableForReportLab(tickers_volatile))
story.append(PageBreak())

# %% [markdown]
# #### Add graph images saved in the timestamped folder

# %%
for file in sorted(os.listdir(reportDir), key=os.path.getmtime):
    if file.endswith('jpg'):
        temp = file
        temp = 'image_'+ temp
        print(temp)
        temp = Image(file)
        #story.append(Spacer(1, 20))
        story.append(temp)
# Out:
# image_highest growth closing price.jpg
# image_highest growth closing pct change.jpg
# image_1.jpg
# image_2.jpg
# image_SP100_total.jpg

# %% [markdown]
# story.append(PageBreak())
# story.append(PrepareTableForReportLab_News_df(news_df))

# %%
doc = SimpleDocTemplate(pdf_file_name, pagesize = landscape(letter), topMargin = inch * .25, bottomMargin = inch * .25)
doc.build(story)

# %%
#open folder
subprocess.run(['open', reportDir], check=True)
# Out:
# CompletedProcess(args=['open', '/Users/reejungkim/Documents/Git/reporting automation/2020-06-29 23-22-08'], returncode=0)

# %%
#Open pdf file generated
subprocess.run(['open', pdf_file_name], check=True)
# Out:
# CompletedProcess(args=['open', 'Report 2020-06-29.pdf'], returncode=0)
